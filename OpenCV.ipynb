# %%
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread("Images/BMW.jpeg")

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("BMW Fan Image")
plt.axis("off")
plt.show()

# %%
# cv.imshow("Image",img)
# cv.waitkey(10000)
# cv.destroyAllWindows()


# IT WONT WORK HERE as we are not using full Python on Linux or Python on windows ... we are using Python on terminal installed on windows 

# It has no UI to display an image so KERNEL Crashes as soon as we run cv COMMANDs, Alternative: using graphs libraires to display
